# %% [markdown]
# # Official Charts Top 100

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup


#Top 100 songs from Apple Music

url = "https://www.officialcharts.com/charts/singles-chart/"
responseofficialcharts = requests.get(url)

soup = BeautifulSoup(responseofficialcharts.content, "html.parser")

responseofficialcharts
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(responseofficialcharts.text,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Official Singles Chart Top 100 | Official Charts
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#f5f2e7" name="msapplication-TileColor"/>
#   <meta content="/favicons/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#f5f2e7" name="theme-color"/>
#   <link href="/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/favicons/site.webmanifest" rel="manifest"/>
#   <link color="#0029f3" href="favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="/favicons/favicon.ico" rel="shortcut icon"/>
#   <script async="async" src="/js/quantcast.js">
#   </script>
# ...

# %%
artist_names=soup.find_all("a", class_="chart-artist text-lg inline-block")

# %%
artist_names
# Out:
# [<a class="chart-artist text-lg inline-block" href="/artist/56601/doja-cat/"><span>DOJA CAT</span></a>,
#  <a class="chart-artist text-lg inline-block" href="/artist/5387/taylor-swift/"><span>TAYLOR SWIFT</span></a>,
#  <a class="chart-artist text-lg inline-block" href="/artist/56921/olivia-rodrigo/"><span>OLIVIA RODRIGO</span></a>,
#  <a class="chart-artist text-lg inline-block" href="/artist/52396/billie-eilish/"><span>BILLIE EILISH</span></a>,
#  <a class="chart-artist text-lg inline-block" href="/artist/53160/peggy-gou/"><span>PEGGY GOU</span></a>,
#  <a class="chart-artist text-lg inline-block" href="/artist/54101/calvin-harris-and-sam-smith/"><span>CALVIN HARRIS &amp; SAM SMITH</span></a>,
#  <a class="chart-artist text-lg inline-block" href="/artist/cassorayed-block-europe/"><span>CASSO/<wbr/>RAYE/<wbr/>D-BLOCK EUROPE</span></a>,
#  <a class="chart-artist text-lg inline-block" href="/artist/becky-hillchase-status/"><span>BECKY HILL/<wbr/>CHASE &amp; STATUS</span></a>,
# ...

# %%
for artist_name in artist_names:
    print(artist_name.text)
# Out:
# DOJA CAT
# TAYLOR SWIFT
# OLIVIA RODRIGO
# BILLIE EILISH
# PEGGY GOU
# CALVIN HARRIS & SAM SMITH
# CASSO/RAYE/D-BLOCK EUROPE
# BECKY HILL/CHASE & STATUS
# FRED AGAIN
# CHASE & STATUS/BOU/FLOWDAN
# GUNNA
# OLIVIA RODRIGO
# DAVE & CENTRAL CEE
# SONNY FODERA/MK/DOUGLAS
# D.O.D
# CHARLI XCX
# DUA LIPA
# MILEY CYRUS
# KYLIE MINOGUE
# KENYA GRACE
# BURNA BOY FT DAVE
# TROYE SIVAN
# ISSEY CROSS
# OLIVER ANTHONY MUSIC
# FLORENCE & THE MACHINE
# STORMZY & RAYE
# BOU FT SLAY
# JUNG KOOK FT LATTO
# SELENA GOMEZ
# LUKE COMBS
# HANNAH LAING & RORO
# BURNA BOY
# CALVIN HARRIS/ELLIE GOULDING
# DAWE/CORRY/HENDERSON
# JAZZY
# RYAN GOSLING
# JAZZY
# MILEY CYRUS
# ANOTR/ABEL BALDER
# NICKI MINAJ/ICE SPICE/AQUA
# TURNO/SKEPSIS/PLANK
# REMA
# TION WAYNE & NINES
# TAYLOR SWIFT
# JORJA SMITH
# NICKI MINAJ
# SZA
# RUDIMENTAL/CHARLOTTEPLANK/VIBE
# TRAVIS SCOTT FT DRAKE
# ZACH BRYAN FT KACEY MUSGRAVES
# SWITCH DISCO & ELLA HENDERSON
# BYRON MESSIA
# DOJA CAT
# BILLY GILLIES FT HANNAH BOLEYN
# DAVID KUSHNER
# ...

# %%
artists= []

for artist_name in artist_names:
    artists.append(artist_name.text)
    
artists
# Out:
# ['DOJA CAT',
#  'TAYLOR SWIFT',
#  'OLIVIA RODRIGO',
#  'BILLIE EILISH',
#  'PEGGY GOU',
#  'CALVIN HARRIS & SAM SMITH',
#  'CASSO/RAYE/D-BLOCK EUROPE',
#  'BECKY HILL/CHASE & STATUS',
#  'FRED AGAIN',
#  'CHASE & STATUS/BOU/FLOWDAN',
#  'GUNNA',
#  'OLIVIA RODRIGO',
#  'DAVE & CENTRAL CEE',
#  'SONNY FODERA/MK/DOUGLAS',
#  'D.O.D',
#  'CHARLI XCX',
#  'DUA LIPA',
#  'MILEY CYRUS',
#  'KYLIE MINOGUE',
#  'KENYA GRACE',
#  'BURNA BOY FT DAVE',
#  'TROYE SIVAN',
#  'ISSEY CROSS',
#  'OLIVER ANTHONY MUSIC',
#  'FLORENCE & THE MACHINE',
#  'STORMZY & RAYE',
#  'BOU FT SLAY',
#  'JUNG KOOK FT LATTO',
#  'SELENA GOMEZ',
#  'LUKE COMBS',
#  'HANNAH LAING & RORO',
#  'BURNA BOY',
#  'CALVIN HARRIS/ELLIE GOULDING',
#  'DAWE/CORRY/HENDERSON',
#  'JAZZY',
#  'RYAN GOSLING',
#  'JAZZY',
#  'MILEY CYRUS',
#  'ANOTR/ABEL BALDER',
#  'NICKI MINAJ/ICE SPICE/AQUA',
#  'TURNO/SKEPSIS/PLANK',
#  'REMA',
#  'TION WAYNE & NINES',
#  'TAYLOR SWIFT',
#  'JORJA SMITH',
#  'NICKI MINAJ',
#  'SZA',
# ...

# %%
len(artist_names)
# Out:
# 100

# %%
song_names = soup.select('.movement-icon+ span')
song_names
# Out:
# [<span>PAINT THE TOWN RED</span>,
#  <span>CRUEL SUMMER</span>,
#  <span>VAMPIRE</span>,
#  <span>WHAT WAS I MADE FOR</span>,
#  <span>(IT GOES LIKE) NANANA</span>,
#  <span>DESIRE</span>,
#  <span>PRADA</span>,
#  <span>DISCONNECT</span>,
#  <span>ADORE U</span>,
#  <span>BADDADAN</span>,
#  <span>FUKUMEAN</span>,
#  <span>BAD IDEA RIGHT</span>,
#  <span>SPRINTER</span>,
#  <span>ASKING</span>,
#  <span>SO MUCH IN LOVE</span>,
#  <span>SPEED DRIVE (FROM BARBIE THE ALBUM)</span>,
#  <span>DANCE THE NIGHT (FROM BARBIE THE ALBUM)</span>,
#  <span>USED TO BE YOUNG</span>,
#  <span>TENSION</span>,
#  <span>STRANGERS</span>,
#  <span>CHEAT ON ME</span>,
#  <span>RUSH</span>,
#  <span>BITTERSWEET GOODBYE</span>,
#  <span>RICH MEN NORTH OF RICHMOND</span>,
#  <span>DOG DAYS ARE OVER</span>,
#  <span>THE WEEKEND</span>,
#  <span>CLOSER</span>,
#  <span>SEVEN</span>,
#  <span>SINGLE SOON</span>,
#  <span>FAST CAR</span>,
#  <span>GOOD LOVE</span>,
#  <span>CITY BOYS</span>,
# ...

# %%
for song in song_names:
    print(song.text.strip())
# Out:
# PAINT THE TOWN RED
# CRUEL SUMMER
# VAMPIRE
# WHAT WAS I MADE FOR
# (IT GOES LIKE) NANANA
# DESIRE
# PRADA
# DISCONNECT
# ADORE U
# BADDADAN
# FUKUMEAN
# BAD IDEA RIGHT
# SPRINTER
# ASKING
# SO MUCH IN LOVE
# SPEED DRIVE (FROM BARBIE THE ALBUM)
# DANCE THE NIGHT (FROM BARBIE THE ALBUM)
# USED TO BE YOUNG
# TENSION
# STRANGERS
# CHEAT ON ME
# RUSH
# BITTERSWEET GOODBYE
# RICH MEN NORTH OF RICHMOND
# DOG DAYS ARE OVER
# THE WEEKEND
# CLOSER
# SEVEN
# SINGLE SOON
# FAST CAR
# GOOD LOVE
# CITY BOYS
# MIRACLE
# 0800 HEAVEN
# FEEL IT
# I'M JUST KEN (FROM BARBIE THE ALBUM)
# GIVING ME
# FLOWERS
# RELAX MY EYES
# BARBIE WORLD (FROM BARBIE THE ALBUM)
# RAVE OUT
# CALM DOWN
# AMEN
# ANTI-HERO
# LITTLE THINGS
# LAST TIME I SAW YOU
# SNOOZE
# DANCING IS HEALING
# MELTDOWN
# I REMEMBER EVERYTHING
# REACT
# TALIBANS
# DEMONS
# DNA (LOVING YOU)
# DAYLIGHT
# AS IT WAS
# PARTY ALL THE TIME
# TELEKINESIS
# POPULAR
# DRINKIN'
# UNHEALTHY
# MR BRIGHTSIDE
# I KNOW
# UNAVAILABLE
# HIGHS & LOWS
# MERIDIAN
# ...

# %%
cleaned_songs = [song.text for song in song_names]
cleaned_songs
# Out:
# ['PAINT THE TOWN RED',
#  'CRUEL SUMMER',
#  'VAMPIRE',
#  'WHAT WAS I MADE FOR',
#  '(IT GOES LIKE) NANANA',
#  'DESIRE',
#  'PRADA',
#  'DISCONNECT',
#  'ADORE U',
#  'BADDADAN',
#  'FUKUMEAN',
#  'BAD IDEA RIGHT',
#  'SPRINTER',
#  'ASKING',
#  'SO MUCH IN LOVE',
#  'SPEED DRIVE (FROM BARBIE THE ALBUM)',
#  'DANCE THE NIGHT (FROM BARBIE THE ALBUM)',
#  'USED TO BE YOUNG',
#  'TENSION',
#  'STRANGERS',
#  'CHEAT ON ME',
#  'RUSH',
#  'BITTERSWEET GOODBYE',
#  'RICH MEN NORTH OF RICHMOND',
#  'DOG DAYS ARE OVER',
#  'THE WEEKEND',
#  'CLOSER',
#  'SEVEN',
#  'SINGLE SOON',
#  'FAST CAR',
#  'GOOD LOVE',
#  'CITY BOYS',
#  'MIRACLE',
#  '0800 HEAVEN',
#  'FEEL IT',
#  "I'M JUST KEN (FROM BARBIE THE ALBUM)",
#  'GIVING ME',
#  'FLOWERS',
#  'RELAX MY EYES',
#  'BARBIE WORLD (FROM BARBIE THE ALBUM)',
#  'RAVE OUT',
#  'CALM DOWN',
#  'AMEN',
#  'ANTI-HERO',
#  'LITTLE THINGS',
#  'LAST TIME I SAW YOU',
#  'SNOOZE',
#  'DANCING IS HEALING',
#  'MELTDOWN',
#  'I REMEMBER EVERYTHING',
# ...

# %%
cleaned_songs = [song.text for song in song_names]
cleaned_songs
# Out:
# ['PAINT THE TOWN RED',
#  'CRUEL SUMMER',
#  'VAMPIRE',
#  'WHAT WAS I MADE FOR',
#  '(IT GOES LIKE) NANANA',
#  'DESIRE',
#  'PRADA',
#  'DISCONNECT',
#  'ADORE U',
#  'BADDADAN',
#  'FUKUMEAN',
#  'BAD IDEA RIGHT',
#  'SPRINTER',
#  'ASKING',
#  'SO MUCH IN LOVE',
#  'SPEED DRIVE (FROM BARBIE THE ALBUM)',
#  'DANCE THE NIGHT (FROM BARBIE THE ALBUM)',
#  'USED TO BE YOUNG',
#  'TENSION',
#  'STRANGERS',
#  'CHEAT ON ME',
#  'RUSH',
#  'BITTERSWEET GOODBYE',
#  'RICH MEN NORTH OF RICHMOND',
#  'DOG DAYS ARE OVER',
#  'THE WEEKEND',
#  'CLOSER',
#  'SEVEN',
#  'SINGLE SOON',
#  'FAST CAR',
#  'GOOD LOVE',
#  'CITY BOYS',
#  'MIRACLE',
#  '0800 HEAVEN',
#  'FEEL IT',
#  "I'M JUST KEN (FROM BARBIE THE ALBUM)",
#  'GIVING ME',
#  'FLOWERS',
#  'RELAX MY EYES',
#  'BARBIE WORLD (FROM BARBIE THE ALBUM)',
#  'RAVE OUT',
#  'CALM DOWN',
#  'AMEN',
#  'ANTI-HERO',
#  'LITTLE THINGS',
#  'LAST TIME I SAW YOU',
#  'SNOOZE',
#  'DANCING IS HEALING',
#  'MELTDOWN',
#  'I REMEMBER EVERYTHING',
# ...

# %%
songs=cleaned_songs
songs
# Out:
# ['PAINT THE TOWN RED',
#  'CRUEL SUMMER',
#  'VAMPIRE',
#  'WHAT WAS I MADE FOR',
#  '(IT GOES LIKE) NANANA',
#  'DESIRE',
#  'PRADA',
#  'DISCONNECT',
#  'ADORE U',
#  'BADDADAN',
#  'FUKUMEAN',
#  'BAD IDEA RIGHT',
#  'SPRINTER',
#  'ASKING',
#  'SO MUCH IN LOVE',
#  'SPEED DRIVE (FROM BARBIE THE ALBUM)',
#  'DANCE THE NIGHT (FROM BARBIE THE ALBUM)',
#  'USED TO BE YOUNG',
#  'TENSION',
#  'STRANGERS',
#  'CHEAT ON ME',
#  'RUSH',
#  'BITTERSWEET GOODBYE',
#  'RICH MEN NORTH OF RICHMOND',
#  'DOG DAYS ARE OVER',
#  'THE WEEKEND',
#  'CLOSER',
#  'SEVEN',
#  'SINGLE SOON',
#  'FAST CAR',
#  'GOOD LOVE',
#  'CITY BOYS',
#  'MIRACLE',
#  '0800 HEAVEN',
#  'FEEL IT',
#  "I'M JUST KEN (FROM BARBIE THE ALBUM)",
#  'GIVING ME',
#  'FLOWERS',
#  'RELAX MY EYES',
#  'BARBIE WORLD (FROM BARBIE THE ALBUM)',
#  'RAVE OUT',
#  'CALM DOWN',
#  'AMEN',
#  'ANTI-HERO',
#  'LITTLE THINGS',
#  'LAST TIME I SAW YOU',
#  'SNOOZE',
#  'DANCING IS HEALING',
#  'MELTDOWN',
#  'I REMEMBER EVERYTHING',
# ...

# %%
len(songs)
# Out:
# 100

# %%
len(artists)
# Out:
# 100

# %%
songs
# Out:
# ['PAINT THE TOWN RED',
#  'CRUEL SUMMER',
#  'VAMPIRE',
#  'WHAT WAS I MADE FOR',
#  '(IT GOES LIKE) NANANA',
#  'DESIRE',
#  'PRADA',
#  'DISCONNECT',
#  'ADORE U',
#  'BADDADAN',
#  'FUKUMEAN',
#  'BAD IDEA RIGHT',
#  'SPRINTER',
#  'ASKING',
#  'SO MUCH IN LOVE',
#  'SPEED DRIVE (FROM BARBIE THE ALBUM)',
#  'DANCE THE NIGHT (FROM BARBIE THE ALBUM)',
#  'USED TO BE YOUNG',
#  'TENSION',
#  'STRANGERS',
#  'CHEAT ON ME',
#  'RUSH',
#  'BITTERSWEET GOODBYE',
#  'RICH MEN NORTH OF RICHMOND',
#  'DOG DAYS ARE OVER',
#  'THE WEEKEND',
#  'CLOSER',
#  'SEVEN',
#  'SINGLE SOON',
#  'FAST CAR',
#  'GOOD LOVE',
#  'CITY BOYS',
#  'MIRACLE',
#  '0800 HEAVEN',
#  'FEEL IT',
#  "I'M JUST KEN (FROM BARBIE THE ALBUM)",
#  'GIVING ME',
#  'FLOWERS',
#  'RELAX MY EYES',
#  'BARBIE WORLD (FROM BARBIE THE ALBUM)',
#  'RAVE OUT',
#  'CALM DOWN',
#  'AMEN',
#  'ANTI-HERO',
#  'LITTLE THINGS',
#  'LAST TIME I SAW YOU',
#  'SNOOZE',
#  'DANCING IS HEALING',
#  'MELTDOWN',
#  'I REMEMBER EVERYTHING',
# ...

# %%
artists
# Out:
# ['DOJA CAT',
#  'TAYLOR SWIFT',
#  'OLIVIA RODRIGO',
#  'BILLIE EILISH',
#  'PEGGY GOU',
#  'CALVIN HARRIS & SAM SMITH',
#  'CASSO/RAYE/D-BLOCK EUROPE',
#  'BECKY HILL/CHASE & STATUS',
#  'FRED AGAIN',
#  'CHASE & STATUS/BOU/FLOWDAN',
#  'GUNNA',
#  'OLIVIA RODRIGO',
#  'DAVE & CENTRAL CEE',
#  'SONNY FODERA/MK/DOUGLAS',
#  'D.O.D',
#  'CHARLI XCX',
#  'DUA LIPA',
#  'MILEY CYRUS',
#  'KYLIE MINOGUE',
#  'KENYA GRACE',
#  'BURNA BOY FT DAVE',
#  'TROYE SIVAN',
#  'ISSEY CROSS',
#  'OLIVER ANTHONY MUSIC',
#  'FLORENCE & THE MACHINE',
#  'STORMZY & RAYE',
#  'BOU FT SLAY',
#  'JUNG KOOK FT LATTO',
#  'SELENA GOMEZ',
#  'LUKE COMBS',
#  'HANNAH LAING & RORO',
#  'BURNA BOY',
#  'CALVIN HARRIS/ELLIE GOULDING',
#  'DAWE/CORRY/HENDERSON',
#  'JAZZY',
#  'RYAN GOSLING',
#  'JAZZY',
#  'MILEY CYRUS',
#  'ANOTR/ABEL BALDER',
#  'NICKI MINAJ/ICE SPICE/AQUA',
#  'TURNO/SKEPSIS/PLANK',
#  'REMA',
#  'TION WAYNE & NINES',
#  'TAYLOR SWIFT',
#  'JORJA SMITH',
#  'NICKI MINAJ',
#  'SZA',
# ...

# %%
len(artists)
# Out:
# 100

# %%
import pandas as pd

# %%
data={'Artists':artists, 'Songs':songs}

# %%
data
# Out:
# {'Artists': ['DOJA CAT',
#   'TAYLOR SWIFT',
#   'OLIVIA RODRIGO',
#   'BILLIE EILISH',
#   'PEGGY GOU',
#   'CALVIN HARRIS & SAM SMITH',
#   'CASSO/RAYE/D-BLOCK EUROPE',
#   'BECKY HILL/CHASE & STATUS',
#   'FRED AGAIN',
#   'CHASE & STATUS/BOU/FLOWDAN',
#   'GUNNA',
#   'OLIVIA RODRIGO',
#   'DAVE & CENTRAL CEE',
#   'SONNY FODERA/MK/DOUGLAS',
#   'D.O.D',
#   'CHARLI XCX',
#   'DUA LIPA',
#   'MILEY CYRUS',
#   'KYLIE MINOGUE',
#   'KENYA GRACE',
#   'BURNA BOY FT DAVE',
#   'TROYE SIVAN',
#   'ISSEY CROSS',
#   'OLIVER ANTHONY MUSIC',
#   'FLORENCE & THE MACHINE',
#   'STORMZY & RAYE',
#   'BOU FT SLAY',
#   'JUNG KOOK FT LATTO',
#   'SELENA GOMEZ',
#   'LUKE COMBS',
#   'HANNAH LAING & RORO',
#   'BURNA BOY',
#   'CALVIN HARRIS/ELLIE GOULDING',
#   'DAWE/CORRY/HENDERSON',
#   'JAZZY',
#   'RYAN GOSLING',
#   'JAZZY',
#   'MILEY CYRUS',
#   'ANOTR/ABEL BALDER',
#   'NICKI MINAJ/ICE SPICE/AQUA',
#   'TURNO/SKEPSIS/PLANK',
#   'REMA',
#   'TION WAYNE & NINES',
#   'TAYLOR SWIFT',
# ...

# %%
Top100_OfficialCharts=pd.DataFrame(data)

# %%
Top100_OfficialCharts
# Out:
#                      Artists                  Songs
# 0                   DOJA CAT     PAINT THE TOWN RED
# 1               TAYLOR SWIFT           CRUEL SUMMER
# 2             OLIVIA RODRIGO                VAMPIRE
# 3              BILLIE EILISH    WHAT WAS I MADE FOR
# 4                  PEGGY GOU  (IT GOES LIKE) NANANA
# ..                       ...                    ...
# 95  ZWE1HVNDXR & YATASHIGANG        LOVELY BASTARDS
# 96              PAUL RUSSELL          LIL BOO THANG
# 97             FLEETWOOD MAC        GO YOUR OWN WAY
# 98                  NEWJEANS              SUPER SHY
# 99                SAM FENDER  SEVENTEEN GOING UNDER
#
# [100 rows x 2 columns]

# %% [markdown]
# # TOP 100 SONGS FROM LAST DECADE - BILLBOARD

# %%
url='https://www.billboard.com/charts/decade-end/hot-100/'

# %%
billboardlastdecade=requests.get(url)

# %%
billboardlastdecade
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(billboardlastdecade.text,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 6]>
# <html id="ie6" lang="en-US">
# <![endif]-->
# <!--[if IE 7]>
# <html id="ie7" lang="en-US">
# <![endif]-->
# <!--[if IE 8]>
# <html id="ie8" lang="en-US">
# <![endif]-->
# <!--[if !(IE 6) | !(IE 7) | !(IE 8) ]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#    <!-- Add to home screen for iOS -->
#    <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#    <link href="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/app/icons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#    <!-- Tile icons for Windows -->
#    <meta content="https://www.billboard.com/wp-content/themes/vip/pmc-billboard-2021/assets/app/browserconfig.xml" name="msapplication-config"/>
# ...

# %%
firstsong = soup.find_all("h3", class_=("c-title a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max u-letter-spacing-0028@tablet"))

# %%
firstsong
# Out:
# [<h3 class="c-title a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max u-letter-spacing-0028@tablet" id="title-of-a-story">
#
#
#
#
#  					Uptown Funk!
#
#  </h3>]

# %%
for elements in firstsong:
    print(elements.text)
# Out:
#
#
#
# 					Uptown Funk!

# %%
firstsong = soup.find_all("h3", class_="c-title a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max u-letter-spacing-0028@tablet")

firstsonglist = []

for element in firstsong:
    firstsonglist.append(element.text)

# %%
firstsonglist
# Out:
# ['\n\n\t\n\t\n\t\t\n\t\t\t\t\tUptown Funk!\t\t\n\t\n']

# %%
firstsonglist = [element.text.strip() for element in firstsong]

# %%
firstsonglist
# Out:
# ['Uptown Funk!']

# %%
songs99= soup.find_all("h3",class_ ="c-title a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max")

# %%
songs99
# Out:
# [<h3 class="c-title a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max" id="title-of-a-story">
#
#
#
#
#  					Party Rock Anthem
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max" id="title-of-a-story">
#
#
#
#
#  					Shape Of You
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max" id="title-of-a-story">
#
#
#
#
#  					Closer
#
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max" id="title-of-a-story">
#
#
#
#
#  					Girls Like You
#
#  </h3>,
# ...

# %%
songs99list=[element.text.strip() for element in songs99]

# %%
songs99list
# Out:
# ['Party Rock Anthem',
#  'Shape Of You',
#  'Closer',
#  'Girls Like You',
#  'We Found Love',
#  'Old Town Road',
#  'Somebody That I Used To Know',
#  'Despacito',
#  'Rolling In The Deep',
#  'Sunflower (Spider-Man: Into The Spider-Verse)',
#  'Without Me',
#  'Call Me Maybe',
#  'Blurred Lines',
#  'Perfect',
#  'Sicko Mode',
#  'All About That Bass',
#  'Royals',
#  "God's Plan",
#  'Moves Like Jagger',
#  'Happy',
#  'Just The Way You Are',
#  'Rockstar',
#  'TiK ToK',
#  'See You Again',
#  'Dark Horse',
#  'Thrift Shop',
#  'One More Night',
#  'We Are Young',
#  "That's What I Like",
#  'The Hills',
#  'All Of Me',
#  'Happier',
#  'Shake It Off',
#  'One Dance',
#  'Radioactive',
#  'Sexy And I Know It',
#  'Someone Like You',
#  'Counting Stars',
#  'E.T.',
#  'Trap Queen',
#  'Love Yourself',
#  'Firework',
#  'Give Me Everything',
#  'Locked Out Of Heaven',
#  'Love The Way You Lie',
#  'Thinking Out Loud',
#  'Sorry',
#  'California Gurls',
#  'Dynamite',
# ...

# %%
song3=firstsonglist + songs99list

# %%
song3
# Out:
# ['Uptown Funk!',
#  'Party Rock Anthem',
#  'Shape Of You',
#  'Closer',
#  'Girls Like You',
#  'We Found Love',
#  'Old Town Road',
#  'Somebody That I Used To Know',
#  'Despacito',
#  'Rolling In The Deep',
#  'Sunflower (Spider-Man: Into The Spider-Verse)',
#  'Without Me',
#  'Call Me Maybe',
#  'Blurred Lines',
#  'Perfect',
#  'Sicko Mode',
#  'All About That Bass',
#  'Royals',
#  "God's Plan",
#  'Moves Like Jagger',
#  'Happy',
#  'Just The Way You Are',
#  'Rockstar',
#  'TiK ToK',
#  'See You Again',
#  'Dark Horse',
#  'Thrift Shop',
#  'One More Night',
#  'We Are Young',
#  "That's What I Like",
#  'The Hills',
#  'All Of Me',
#  'Happier',
#  'Shake It Off',
#  'One Dance',
#  'Radioactive',
#  'Sexy And I Know It',
#  'Someone Like You',
#  'Counting Stars',
#  'E.T.',
#  'Trap Queen',
#  'Love Yourself',
#  'Firework',
#  'Give Me Everything',
#  'Locked Out Of Heaven',
#  'Love The Way You Lie',
#  'Thinking Out Loud',
#  'Sorry',
#  'California Gurls',
# ...

# %%
firstartist= soup.find_all("span",class_="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block u-font-size-20@tablet")

# %%
firstartist
# Out:
# [<span class="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block u-font-size-20@tablet">
#
#  	Mark Ronson Featuring Bruno Mars
#  </span>]

# %%
firstartist= soup.find_all("span",class_="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block u-font-size-20@tablet")
firstartistlist = []

for element in firstartist:
    firstartistlist.append(element.text)

# %%
firstartistlist
# Out:
# ['\n\t\n\tMark Ronson Featuring Bruno Mars\n']

# %%
firstartistlist = [element.text.strip() for element in firstartist]

# %%
firstartistlist
# Out:
# ['Mark Ronson Featuring Bruno Mars']

# %%
artists99= soup.find_all("span",class_ ="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block")

# %%
artists99
# Out:
# [<span class="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block">
#
#  	LMFAO Featuring Lauren Bennett &amp; GoonRock
#  </span>,
#  <span class="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block">
#
#  	Ed Sheeran
#  </span>,
#  <span class="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block">
#
#  	The Chainsmokers Featuring Halsey
#  </span>,
#  <span class="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block">
#
#  	Maroon 5 Featuring Cardi B
#  </span>,
#  <span class="c-label a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block">
#
#  	Rihanna Featuring Calvin Harris
#  </span>,
# ...

# %%
artists99list=[element.text.strip() for element in artists99]

# %%
artists99list
# Out:
# ['LMFAO Featuring Lauren Bennett & GoonRock',
#  'Ed Sheeran',
#  'The Chainsmokers Featuring Halsey',
#  'Maroon 5 Featuring Cardi B',
#  'Rihanna Featuring Calvin Harris',
#  'Lil Nas X Featuring Billy Ray Cyrus',
#  'Gotye Featuring Kimbra',
#  'Luis Fonsi & Daddy Yankee Featuring Justin Bieber',
#  'Adele',
#  'Post Malone & Swae Lee',
#  'Halsey',
#  'Carly Rae Jepsen',
#  'Robin Thicke Featuring T.I. + Pharrell',
#  'Ed Sheeran',
#  'Travis Scott',
#  'Meghan Trainor',
#  'Lorde',
#  'Drake',
#  'Maroon 5 Featuring Christina Aguilera',
#  'Pharrell Williams',
#  'Bruno Mars',
#  'Post Malone Featuring 21 Savage',
#  'Ke$ha',
#  'Wiz Khalifa Featuring Charlie Puth',
#  'Katy Perry Featuring Juicy J',
#  'Macklemore & Ryan Lewis Featuring Wanz',
#  'Maroon 5',
#  'fun. Featuring Janelle Monae',
#  'Bruno Mars',
#  'The Weeknd',
#  'John Legend',
#  'Marshmello & Bastille',
#  'Taylor Swift',
#  'Drake Featuring WizKid & Kyla',
#  'Imagine Dragons',
#  'LMFAO',
#  'Adele',
# ...

# %%
len(artists99)
# Out:
# 99

# %%
len(songs99)
# Out:
# 99

# %%
artists3=firstartistlist + artists99list

# %%
artists3
# Out:
# ['Mark Ronson Featuring Bruno Mars',
#  'LMFAO Featuring Lauren Bennett & GoonRock',
#  'Ed Sheeran',
#  'The Chainsmokers Featuring Halsey',
#  'Maroon 5 Featuring Cardi B',
#  'Rihanna Featuring Calvin Harris',
#  'Lil Nas X Featuring Billy Ray Cyrus',
#  'Gotye Featuring Kimbra',
#  'Luis Fonsi & Daddy Yankee Featuring Justin Bieber',
#  'Adele',
#  'Post Malone & Swae Lee',
#  'Halsey',
#  'Carly Rae Jepsen',
#  'Robin Thicke Featuring T.I. + Pharrell',
#  'Ed Sheeran',
#  'Travis Scott',
#  'Meghan Trainor',
#  'Lorde',
#  'Drake',
#  'Maroon 5 Featuring Christina Aguilera',
#  'Pharrell Williams',
#  'Bruno Mars',
#  'Post Malone Featuring 21 Savage',
#  'Ke$ha',
#  'Wiz Khalifa Featuring Charlie Puth',
#  'Katy Perry Featuring Juicy J',
#  'Macklemore & Ryan Lewis Featuring Wanz',
#  'Maroon 5',
#  'fun. Featuring Janelle Monae',
#  'Bruno Mars',
#  'The Weeknd',
#  'John Legend',
#  'Marshmello & Bastille',
#  'Taylor Swift',
#  'Drake Featuring WizKid & Kyla',
# ...

# %%
song3
# Out:
# ['Uptown Funk!',
#  'Party Rock Anthem',
#  'Shape Of You',
#  'Closer',
#  'Girls Like You',
#  'We Found Love',
#  'Old Town Road',
#  'Somebody That I Used To Know',
#  'Despacito',
#  'Rolling In The Deep',
#  'Sunflower (Spider-Man: Into The Spider-Verse)',
#  'Without Me',
#  'Call Me Maybe',
#  'Blurred Lines',
#  'Perfect',
#  'Sicko Mode',
#  'All About That Bass',
#  'Royals',
#  "God's Plan",
#  'Moves Like Jagger',
#  'Happy',
#  'Just The Way You Are',
#  'Rockstar',
#  'TiK ToK',
#  'See You Again',
#  'Dark Horse',
#  'Thrift Shop',
#  'One More Night',
#  'We Are Young',
#  "That's What I Like",
#  'The Hills',
#  'All Of Me',
#  'Happier',
#  'Shake It Off',
#  'One Dance',
#  'Radioactive',
#  'Sexy And I Know It',
#  'Someone Like You',
#  'Counting Stars',
#  'E.T.',
#  'Trap Queen',
#  'Love Yourself',
#  'Firework',
#  'Give Me Everything',
#  'Locked Out Of Heaven',
#  'Love The Way You Lie',
#  'Thinking Out Loud',
#  'Sorry',
#  'California Gurls',
# ...

# %%
len(artists3)
# Out:
# 100

# %%
len(song3)
# Out:
# 100

# %%
data3={"Artists":artists3,"Songs":song3}

# %%
df=pd.DataFrame(data3)

# %%
df
# Out:
#                                       Artists              Songs
# 0            Mark Ronson Featuring Bruno Mars       Uptown Funk!
# 1   LMFAO Featuring Lauren Bennett & GoonRock  Party Rock Anthem
# 2                                  Ed Sheeran       Shape Of You
# 3           The Chainsmokers Featuring Halsey             Closer
# 4                  Maroon 5 Featuring Cardi B     Girls Like You
# ..                                        ...                ...
# 95                                  Desiigner              Panda
# 96               Taio Cruz Featuring Ludacris   Break Your Heart
# 97                                      Drake     In My Feelings
# 98                                Miley Cyrus      Wrecking Ball
# 99                              The Lumineers             Ho Hey
#
# [100 rows x 2 columns]
